# %% [markdown]
# ##  Series de tiempo (Se buscan tendencias, ruido y puede tener comportamiento ciclico)

# %%
import statsmodels.api as sm 
import matplotlib.pyplot as plt

# %%
dta = sm.datasets.co2.load_pandas().data

# %%
dta.plot()
plt.title('Niveles de CO2')
plt.ylabel('Partes por millón')
plt.xlabel('Año')
plt.show()
dta
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
import yfinance as yf
import numpy as np

# %%
ticker_google = 'GOOGL'
start_date = '2018-01-01'
end_date = '2025-12-31'
df_google =yf.download(ticker_google, start=start_date, end=end_date)
# Out:
# C:\Users\Sjvn\AppData\Local\Temp\ipykernel_26760\1873559084.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_google =yf.download(ticker_google, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df_google
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2018-01-02   53.292934   53.430486   52.290351   52.290351  31766000
# 2018-01-03   54.202168   54.429599   53.303864   53.328691  31318000
# 2018-01-04   54.412708   54.825859   54.338225   54.478754  26052000
# 2018-01-05   55.134235   55.297610   54.712644   54.794579  30250000
# 2018-01-08   55.328888   55.574694   55.119831   55.169488  24644000
# ...                ...         ...         ...         ...       ...
# 2025-09-25  245.789993  246.490005  240.740005  244.399994  31020400
# 2025-09-26  246.539993  249.419998  245.970001  247.070007  18503200
# 2025-09-29  244.050003  251.149994  242.770004  247.850006  32505800
# 2025-09-30  243.100006  243.289993  239.250000  242.809998  34700500
# 2025-10-01  240.519897  241.869995  238.610001  240.800003  10452992
#
# [1948 rows x 5 columns]

# %%
df_google['Close'].plot()
plt.title('Eje Normal')
plt.show()

# %%
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1948 entries, 2018-01-02 to 2025-10-01
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Close, GOOGL)   1948 non-null   float64
#  1   (High, GOOGL)    1948 non-null   float64
#  2   (Low, GOOGL)     1948 non-null   float64
#  3   (Open, GOOGL)    1948 non-null   float64
#  4   (Volume, GOOGL)  1948 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 91.3 KB

# %%
df_google['LogClose'] = np.log(df_google['Close'])

# %%
df_google
# Out:
# Price            Close        High         Low        Open    Volume  LogClose
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2018-01-02   53.292934   53.430486   52.290351   52.290351  31766000  3.975804
# 2018-01-03   54.202168   54.429599   53.303864   53.328691  31318000  3.992721
# 2018-01-04   54.412708   54.825859   54.338225   54.478754  26052000  3.996598
# 2018-01-05   55.134235   55.297610   54.712644   54.794579  30250000  4.009771
# 2018-01-08   55.328888   55.574694   55.119831   55.169488  24644000  4.013295
# ...                ...         ...         ...         ...       ...       ...
# 2025-09-25  245.789993  246.490005  240.740005  244.399994  31020400  5.504477
# 2025-09-26  246.539993  249.419998  245.970001  247.070007  18503200  5.507524
# 2025-09-29  244.050003  251.149994  242.770004  247.850006  32505800  5.497373
# 2025-09-30  243.100006  243.289993  239.250000  242.809998  34700500  5.493473
# 2025-10-01  240.519897  241.869995  238.610001  240.800003  10452992  5.482803
#
# [1948 rows x 6 columns]

# %%
df_google['LogClose'].plot()
plt.title('Ejer logaritmico')
plt.show()
